# %%
# %run ../AzureJobs_Dashboard.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/ml_examples/AzureJobs_Dashboard.ipynb in <module>
#       2 runs = get_runs_summary(ws)
#       3 runs = filter(lambda t: 'mskorski_test_job' in t.job_name, runs)
# ----> 4 summary_df = pd.DataFrame(runs)
#       5 summary_df
#
# ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     682         elif is_list_like(data):
#     683             if not isinstance(data, (abc.Sequence, ExtensionArray)):
# --> 684                 data = list(data)
#     685             if len(data) > 0:
#     686                 if is_dataclass(data[0]):
#
# ~/ml_examples/AzureJobs_Dashboard.ipynb in get_runs_summary(ws)
#       9     record = namedtuple('Run_Description',['job_name','run_id','run_status'])
#      10     for exp_name,exp_obj in ws.experiments.items():
# ...
